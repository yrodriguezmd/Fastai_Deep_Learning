# %% [markdown]
# <a href="https://colab.research.google.com/github/yrodriguezmd/Fastai_Deep_Learning/blob/conv_planets_br/Convolution%2C_planets_2021_8_13_11am.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
from fastbook import *
#!pip install fastai -U
import fastai
from fastai.vision.all import *
# Out:
#      |████████████████████████████████| 720 kB 13.2 MB/s
#      |████████████████████████████████| 188 kB 49.0 MB/s
#      |████████████████████████████████| 1.2 MB 36.3 MB/s
#      |████████████████████████████████| 46 kB 2.9 MB/s
#      |████████████████████████████████| 56 kB 4.3 MB/s
#      |████████████████████████████████| 51 kB 394 kB/s
# Mounted at /content/gdrive

# %%
# !pip install jmd_imagescraper
from jmd_imagescraper.core import *
from pathlib import Path

# %%
# complex coloured images, 3 labels

# %%
# iteration 2
root = Path().cwd()/'planets_8'

search = duckduckgo_search

search(root, 'earth','planet earth ', max_results = 750, img_layout=ImgLayout.All)
search(root, 'jupiter','planet jupiter ', max_results = 750, img_layout=ImgLayout.All)
search(root, 'saturn',' planet saturn ', max_results = 750, img_layout=ImgLayout.All)
search(root, 'neptune','planet neptune ', max_results = 750, img_layout=ImgLayout.All)
# Out:
# Duckduckgo search: planet earth
# ...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='750' class='' max='750' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [750/750 00:45<00:00 Images downloaded]
#     </div>
# Duckduckgo search: planet jupiter
# ...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
# ...

# %%
# objective planet differentiation, show colour effect on conv
from jmd_imagescraper.imagecleaner import *
display_image_cleaner(root)

# fast cleaning
# Out:
# ...
# HTML(value='<h2>No images left to display in this folder.</h2>', layout=Layout(visibility='hidden'))
# GridBox(children=(VBox(children=(Image(value=b'', layout="Layout(width='150px')"), Button(description='Delete'…

# %%
# for illustration, no need to save

# %%
#path = Path('/content/planets_2/')

# %%
#path.ls()
# Out:
# (#4) [Path('/content/planets/jupiter'),Path('/content/planets/saturn'),Path('/content/planets/earth'),Path('/content/planets/neptune')]

# %%
#(path/'jupiter').ls()
# Out:
# (#50) [Path('/content/planets/jupiter/020_4ed4840b.jpg'),Path('/content/planets/jupiter/028_9cc1c5e5.jpg'),Path('/content/planets/jupiter/029_6c27040d.jpg'),Path('/content/planets/jupiter/021_77053801.jpg'),Path('/content/planets/jupiter/022_59d551e9.jpg'),Path('/content/planets/jupiter/043_9c4d749a.jpg'),Path('/content/planets/jupiter/046_ba0a8d60.jpg'),Path('/content/planets/jupiter/024_c2b41f60.jpg'),Path('/content/planets/jupiter/039_1f9749ef.jpg'),Path('/content/planets/jupiter/010_94fa650b.jpg')...]

# %%
##### keep!
from PIL import Image, ImageOps
jupiter = Image.open('/content/planets_2/jupiter/020_4ed4840b.jpg')##
show_image(jupiter);

# %%
#### keep
jupiter_t = tensor(jupiter)
jupiter_t.shape
# Out:
# torch.Size([298, 300, 3])

# %%
#150th row, somewhere in the middle
#jupiter_t[150]

# %%
###keep
red = pd.DataFrame(jupiter_t[:,:,0] )
red = red.iloc[25:35,110:120]##
red.style.set_properties().background_gradient('gist_heat')
# Out:
# <style  type="text/css" >
# #T_5d435006_fbbb_11eb_bd81_0242ac1c0002row0_col0,#T_5d435006_fbbb_11eb_bd81_0242ac1c0002row0_col1,#T_5d435006_fbbb_11eb_bd81_0242ac1c0002row0_col2,#T_5d435006_fbbb_11eb_bd81_0242ac1c0002row0_col3,#T_5d435006_fbbb_11eb_bd81_0242ac1c0002row0_col4,#T_5d435006_fbbb_11eb_bd81_0242ac1c0002row0_col5,#T_5d435006_fbbb_11eb_bd81_0242ac1c0002row0_col6,#T_5d435006_fbbb_11eb_bd81_0242ac1c0002row1_col2,#T_5d435006_fbbb_11eb_bd81_0242ac1c0002row2_col9,#T_5d435006_fbbb_11eb_bd81_0242ac1c0002row3_col7,#T_5d435006_fbbb_11eb_bd81_0242ac1c0002row3_col8{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_5d435006_fbbb_11eb_bd81_0242ac1c0002row0_col7{
#             background-color:  #4b0000;
#             color:  #f1f1f1;
#         }#T_5d435006_fbbb_11eb_bd81_0242ac1c0002row0_col8{
#             background-color:  #b70000;
#             color:  #f1f1f1;
#         }#T_5d435006_fbbb_11eb_bd81_0242ac1c0002row0_col9{
# ...

# %%
###keep
green = pd.DataFrame(jupiter_t[:,:,1] )
green = green.iloc[25:35,110:120]##
green.style.set_properties().background_gradient('gist_heat')
# Out:
# <style  type="text/css" >
# #T_6a780e7e_fbbb_11eb_bd81_0242ac1c0002row0_col0,#T_6a780e7e_fbbb_11eb_bd81_0242ac1c0002row0_col1,#T_6a780e7e_fbbb_11eb_bd81_0242ac1c0002row0_col2,#T_6a780e7e_fbbb_11eb_bd81_0242ac1c0002row0_col3,#T_6a780e7e_fbbb_11eb_bd81_0242ac1c0002row0_col4,#T_6a780e7e_fbbb_11eb_bd81_0242ac1c0002row0_col5,#T_6a780e7e_fbbb_11eb_bd81_0242ac1c0002row0_col6,#T_6a780e7e_fbbb_11eb_bd81_0242ac1c0002row5_col9,#T_6a780e7e_fbbb_11eb_bd81_0242ac1c0002row6_col7,#T_6a780e7e_fbbb_11eb_bd81_0242ac1c0002row6_col8{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_6a780e7e_fbbb_11eb_bd81_0242ac1c0002row0_col7,#T_6a780e7e_fbbb_11eb_bd81_0242ac1c0002row8_col9{
#             background-color:  #810000;
#             color:  #f1f1f1;
#         }#T_6a780e7e_fbbb_11eb_bd81_0242ac1c0002row0_col8,#T_6a780e7e_fbbb_11eb_bd81_0242ac1c0002row2_col4{
#             background-color:  #ff7f00;
#             color:  #000000;
# ...

# %%
###keep
blue = pd.DataFrame(jupiter_t[:,:,2] )
blue = blue.iloc[25:35,110:120]##
blue.style.set_properties().background_gradient('gist_heat')
# Out:
# <style  type="text/css" >
# #T_7982b784_fbbb_11eb_bd81_0242ac1c0002row0_col0,#T_7982b784_fbbb_11eb_bd81_0242ac1c0002row0_col1,#T_7982b784_fbbb_11eb_bd81_0242ac1c0002row0_col2,#T_7982b784_fbbb_11eb_bd81_0242ac1c0002row0_col3,#T_7982b784_fbbb_11eb_bd81_0242ac1c0002row0_col4,#T_7982b784_fbbb_11eb_bd81_0242ac1c0002row0_col5,#T_7982b784_fbbb_11eb_bd81_0242ac1c0002row0_col6,#T_7982b784_fbbb_11eb_bd81_0242ac1c0002row5_col9,#T_7982b784_fbbb_11eb_bd81_0242ac1c0002row6_col7,#T_7982b784_fbbb_11eb_bd81_0242ac1c0002row7_col8{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_7982b784_fbbb_11eb_bd81_0242ac1c0002row0_col7{
#             background-color:  #9f0000;
#             color:  #f1f1f1;
#         }#T_7982b784_fbbb_11eb_bd81_0242ac1c0002row0_col8{
#             background-color:  #ff7f00;
#             color:  #000000;
# ...

# %%
#path.ls()
# Out:
# (#4) [Path('/content/planets/jupiter'),Path('/content/planets/saturn'),Path('/content/planets/earth'),Path('/content/planets/neptune')]

# %%
#(path/'/content/planets/jupiter').ls()
# Out:
# (#50) [Path('/content/planets/jupiter/020_4ed4840b.jpg'),Path('/content/planets/jupiter/028_9cc1c5e5.jpg'),Path('/content/planets/jupiter/029_6c27040d.jpg'),Path('/content/planets/jupiter/021_77053801.jpg'),Path('/content/planets/jupiter/022_59d551e9.jpg'),Path('/content/planets/jupiter/043_9c4d749a.jpg'),Path('/content/planets/jupiter/046_ba0a8d60.jpg'),Path('/content/planets/jupiter/024_c2b41f60.jpg'),Path('/content/planets/jupiter/039_1f9749ef.jpg'),Path('/content/planets/jupiter/010_94fa650b.jpg')...]

# %%
# pattern to root name
zip_name = 'planets_8.zip'##

# !rm -f {zip_name}
# !zip -q -r {zip_name} {root}
# zip contains cleaned set

from google.colab import files
files.download(zip_name) 

from google.colab import drive
import shutil

destination_folder = 'planets_8' ## new name

drive.mount('/content/drive/')
folder = Path('/content/drive/My Drive')/destination_folder
folder.mkdir(parents=True, exist_ok = True)

shutil.copyfile(zip_name, str(folder/zip_name))
# Out:
# Mounted at /content/drive/
# '/content/drive/My Drive/planets_8/planets_8.zip'

# %%
# !unzip \*zip && rm *.zip
# Out:
# Archive:  planets_8.zip
#    creating: content/planets_8/
#    creating: content/planets_8/earth/
#   inflating: content/planets_8/earth/488_f9c240c2.jpg
#   inflating: content/planets_8/earth/466_9725dad7.jpg
#   inflating: content/planets_8/earth/478_440513b6.jpg
#   inflating: content/planets_8/earth/656_b467b752.jpg
#   inflating: content/planets_8/earth/215_d943991d.jpg
#   inflating: content/planets_8/earth/694_e8e51cde.jpg
#   inflating: content/planets_8/earth/172_87ada16d.jpg
#   inflating: content/planets_8/earth/058_ba7cc12b.jpg
#   inflating: content/planets_8/earth/714_f131d318.jpg
#   inflating: content/planets_8/earth/062_466a2768.jpg
#   inflating: content/planets_8/earth/069_3c01952d.jpg
#   inflating: content/planets_8/earth/489_d173f820.jpg
#   inflating: content/planets_8/earth/289_ef8a8ee2.jpg
#   inflating: content/planets_8/earth/586_0994e308.jpg
#   inflating: content/planets_8/earth/635_591eb6c9.jpg
#   inflating: content/planets_8/earth/616_c7884460.jpg
# ...

# %%
#Path('/content/planets_2/').ls()
# Out:
# (#4) [Path('/content/planets_2/jupiter'),Path('/content/planets_2/saturn'),Path('/content/planets_2/earth'),Path('/content/planets_2/neptune')]

# %%
path = Path('/content/planets_8')

dblock = DataBlock(
    blocks = (ImageBlock(), CategoryBlock()),
    get_items = get_image_files,
    splitter = RandomSplitter(seed=42, valid_pct=0.2),
    get_y= parent_label,
    item_tfms = Resize(460),#
    batch_tfms = (aug_transforms (size=200, max_rotate=20, max_zoom=1.2)
    )
)

dls = dblock.dataloaders(path/'/content/planets_8/' )
## didn't like Normalize() --> list not callable errors
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:1023: UserWarning: torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  /pytorch/aten/src/ATen/native/BatchLinearAlgebra.cpp:760.)
#   ret = func(*args, **kwargs)

# %%
dblock.summary(path)
# Out:
# Setting-up type transforms pipelines
# ...
# Found 2999 items
# 2 datasets of sizes 2400,599
# Setting up Pipeline: PILBase.create
# Setting up Pipeline: parent_label -> Categorize -- {'vocab': None, 'sort': True, 'add_na': False}
#
# Building one sample
#   Pipeline: PILBase.create
#     starting from
#       /content/planets_8/saturn/246_c5c9abf8.jpg
#     applying PILBase.create gives
#       PILImage mode=RGB size=474x355
#   Pipeline: parent_label -> Categorize -- {'vocab': None, 'sort': True, 'add_na': False}
#     starting from
#       /content/planets_8/saturn/246_c5c9abf8.jpg
#     applying parent_label gives
#       saturn
#     applying Categorize -- {'vocab': None, 'sort': True, 'add_na': False} gives
#       TensorCategory(3)
#
# Final sample: (PILImage mode=RGB size=474x355, TensorCategory(3))
#
#
# ...
# Found 2999 items
# 2 datasets of sizes 2400,599
# Setting up Pipeline: PILBase.create
# ...

# %%
dls.train.show_batch()

# %%
dls.train.show_batch()

# %%
300 - 5 + (2 * (5//2))

# %%
def output(input, ks, s):
  p = ks//2
  x = ( (input - ks + ( 2 * p)) // s) +1
  return x

# %%
output(2, 3,2)
# Out:
# 1

# %%
# input 200x200x3
cnn = sequential(
    (nn.Conv2d(in_channels = 3, out_channels = 8, # 
              kernel_size = 5,
              stride=2,
               padding = 5//2)),# 100
 #   (nn.BatchNorm2d(8)), 
 #   (nn.ReLU()),

    (nn.Conv2d(in_channels = 8, out_channels = 16,
          kernel_size = 5,
          stride=2,
          padding =5//2)), # 50
 #   (nn.BatchNorm2d(16)), 
 #   (nn.ReLU()), 
    
    (nn.Conv2d(in_channels = 16, out_channels = 32,
          kernel_size = 5,
          stride=2,
          padding=5//2)), # 25
 #   (nn.BatchNorm2d(32)), 
 #   (nn.ReLU()),

    (nn.Conv2d(in_channels = 32, out_channels = 64,
          kernel_size = 5,
          stride=2,
          padding=5//2)), # 13
  #  (nn.BatchNorm2d(64)), 
  #  (nn.ReLU()),

    (nn.Conv2d(in_channels = 64, out_channels = 128,
          kernel_size = 5,
          stride=2,
          padding=5//2)), # 7
  #  (nn.BatchNorm2d(128)), 
  #  (nn.ReLU()),

    (nn.Conv2d(in_channels = 128, out_channels = 256,
          kernel_size = 3,
          stride=2,
          padding=3//2)), # 4
 #   (nn.BatchNorm2d(256)), 
 #   (nn.ReLU()),

    (nn.Conv2d(in_channels = 256, out_channels = 512,
          kernel_size = 3,
          stride=2,
          padding=3//2)), # 2
  #  (nn.BatchNorm2d(512)), 
  #  (nn.ReLU()),

    (nn.Conv2d(in_channels = 512, out_channels = 4,##
          kernel_size = 3,
          stride=2,
          padding =3//2)), # 1
          
    Flatten(full=False)
)

# %%
cnn
# Out:
# Sequential(
#   (0): Conv2d(3, 8, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (1): Conv2d(8, 16, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (2): Conv2d(16, 32, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (4): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (5): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (6): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (7): Conv2d(512, 4, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (8): Flatten(full=False)
# )

# %%
# no norm, relu
learn = Learner(dls, cnn,
                loss_func = F.cross_entropy,
                metrics = accuracy,
                cbs = ActivationStats(with_hist=True))
learn.fit(n_epoch = 1, lr = 0.003) #
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/callback/core.py:51: UserWarning: You are shadowing an attribute (modules) that exists in the learner. Use `self.learn.modules` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.555690</td>
#       <td>1.883098</td>
#       <td>0.295493</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.summary()
# Out:
# Sequential (Input shape: 64)
# ...
# Layer (type)         Output Shape         Param #    Trainable
# ...
#                      64 x 8 x 100 x 100
# Conv2d                                    608        True
# ____________________________________________________________________________
#                      64 x 16 x 50 x 50
# Conv2d                                    3216       True
# ____________________________________________________________________________
#                      64 x 32 x 25 x 25
# Conv2d                                    12832      True
# ____________________________________________________________________________
#                      64 x 64 x 13 x 13
# Conv2d                                    51264      True
# ____________________________________________________________________________
#                      64 x 128 x 7 x 7
# Conv2d                                    204928     True
# ____________________________________________________________________________
# ...

# %%
learn.lr_find()
# keep lr 0.003
# Out:
# SuggestedLRs(valley=0.0002290867705596611)

# %%
learn.activation_stats.plot_layer_stats(0)

# %%
learn.activation_stats.plot_layer_stats(-2)

# %%
for r in range(8):
  learn.activation_stats.plot_layer_stats(r)

# %%
learn.activation_stats.color_dim(-2)

# %%
# input 200x200x3
cnn = sequential(
    (nn.Conv2d(in_channels = 3, out_channels = 8, # 
              kernel_size = 5,
              stride=2,
               padding = 5//2)),# 100
 #   (nn.BatchNorm2d(8)), 
    (nn.ReLU()),

    (nn.Conv2d(in_channels = 8, out_channels = 16,
          kernel_size = 5,
          stride=2,
          padding =5//2)), # 50
 #   (nn.BatchNorm2d(16)), 
    (nn.ReLU()), 
    
    (nn.Conv2d(in_channels = 16, out_channels = 32,
          kernel_size = 5,
          stride=2,
          padding=5//2)), # 25
 #   (nn.BatchNorm2d(32)), 
    (nn.ReLU()),

    (nn.Conv2d(in_channels = 32, out_channels = 64,
          kernel_size = 5,
          stride=2,
          padding=5//2)), # 13
  #  (nn.BatchNorm2d(64)), 
    (nn.ReLU()),

    (nn.Conv2d(in_channels = 64, out_channels = 128,
          kernel_size = 5,
          stride=2,
          padding=5//2)), # 7
  #  (nn.BatchNorm2d(128)), 
    (nn.ReLU()),

    (nn.Conv2d(in_channels = 128, out_channels = 256,
          kernel_size = 3,
          stride=2,
          padding=3//2)), # 4
 #   (nn.BatchNorm2d(256)), 
    (nn.ReLU()),

    (nn.Conv2d(in_channels = 256, out_channels = 512,
          kernel_size = 3,
          stride=2,
          padding=3//2)), # 2
  #  (nn.BatchNorm2d(512)), 
    (nn.ReLU()),

    (nn.Conv2d(in_channels = 512, out_channels = 4,
          kernel_size = 3,
          stride=2,
          padding =3//2)), # 1
          
    (Flatten())
)

# %%
cnn
# Out:
# Sequential(
#   (0): Conv2d(3, 8, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (1): ReLU()
#   (2): Conv2d(8, 16, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (3): ReLU()
#   (4): Conv2d(16, 32, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (5): ReLU()
#   (6): Conv2d(32, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (7): ReLU()
#   (8): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (9): ReLU()
#   (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (11): ReLU()
#   (12): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (13): ReLU()
#   (14): Conv2d(512, 4, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (15): Flatten(full=False)
# )

# %%
# no norm
# with relu, lr 0.001
learn = Learner(dls, cnn,
                loss_func = F.cross_entropy,
                metrics = accuracy,
                cbs = ActivationStats(with_hist=True))
learn.fit(n_epoch = 1, lr = 0.003) #
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/callback/core.py:51: UserWarning: You are shadowing an attribute (modules) that exists in the learner. Use `self.learn.modules` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.321390</td>
#       <td>1.193089</td>
#       <td>0.460768</td>
#       <td>00:23</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.summary()
# Out:
# Sequential (Input shape: 64)
# ...
# Layer (type)         Output Shape         Param #    Trainable
# ...
#                      64 x 8 x 100 x 100
# Conv2d                                    608        True
# ReLU
# ____________________________________________________________________________
#                      64 x 16 x 50 x 50
# Conv2d                                    3216       True
# ReLU
# ____________________________________________________________________________
#                      64 x 32 x 25 x 25
# Conv2d                                    12832      True
# ReLU
# ____________________________________________________________________________
#                      64 x 64 x 13 x 13
# Conv2d                                    51264      True
# ReLU
# ____________________________________________________________________________
#                      64 x 128 x 7 x 7
# Conv2d                                    204928     True
# ReLU
# ...

# %%
for r in range(8):
  learn.activation_stats.plot_layer_stats(r)

# %%
learn.activation_stats.color_dim(-2)

# %%
# input 200x200x3
cnn = sequential(
    (nn.Conv2d(in_channels = 3, out_channels = 8, # 
              kernel_size = 5,
              stride=2,
               padding = 5//2)),# 100
    (nn.BatchNorm2d(8)), 
    (nn.ReLU()),

    (nn.Conv2d(in_channels = 8, out_channels = 16,
          kernel_size = 5,
          stride=2,
          padding =5//2)), # 50
    (nn.BatchNorm2d(16)), 
    (nn.ReLU()), 
    
    (nn.Conv2d(in_channels = 16, out_channels = 32,
          kernel_size = 5,
          stride=2,
          padding=5//2)), # 25
    (nn.BatchNorm2d(32)), 
    (nn.ReLU()),

    (nn.Conv2d(in_channels = 32, out_channels = 64,
          kernel_size = 5,
          stride=2,
          padding=5//2)), # 13
    (nn.BatchNorm2d(64)), 
    (nn.ReLU()),

    (nn.Conv2d(in_channels = 64, out_channels = 128,
          kernel_size = 5,
          stride=2,
          padding=5//2)), # 7
    (nn.BatchNorm2d(128)), 
    (nn.ReLU()),

    (nn.Conv2d(in_channels = 128, out_channels = 256,
          kernel_size = 3,
          stride=2,
          padding=3//2)), # 4
    (nn.BatchNorm2d(256)), 
    (nn.ReLU()),

    (nn.Conv2d(in_channels = 256, out_channels = 512,
          kernel_size = 3,
          stride=2,
          padding=3//2)), # 2
    (nn.BatchNorm2d(512)), 
    (nn.ReLU()),

    (nn.Conv2d(in_channels = 512, out_channels = 4,##
          kernel_size = 3,
          stride=2,
          padding =3//2)), # 1
          
    (Flatten())
)

# %%
cnn
# Out:
# Sequential(
#   (0): Conv2d(3, 8, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Conv2d(8, 16, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): ReLU()
#   (6): Conv2d(16, 32, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): ReLU()
#   (9): Conv2d(32, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): ReLU()
#   (12): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (13): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): ReLU()
#   (15): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
# ...

# %%
# with norm, relu, lr 0.003
learn = Learner(dls, cnn,
                loss_func = F.cross_entropy,
                metrics = accuracy,
                cbs = ActivationStats(with_hist=True))
learn.fit(n_epoch = 1, lr = 0.003) #
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/callback/core.py:51: UserWarning: You are shadowing an attribute (modules) that exists in the learner. Use `self.learn.modules` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.352808</td>
#       <td>1.198202</td>
#       <td>0.497496</td>
#       <td>00:28</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.activation_stats.plot_layer_stats(0)

# %%
for r in range(8):
  learn.activation_stats.plot_layer_stats(r)

# %%
learn.activation_stats.color_dim(-2)

# %%
# fit_one_cycle, lr 0.003
learn = Learner(dls, cnn,
                loss_func = F.cross_entropy,
                metrics = accuracy,
                cbs = ActivationStats(with_hist=True))
learn.fit_one_cycle(n_epoch = 1, lr_max = 0.003) #
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/callback/core.py:51: UserWarning: You are shadowing an attribute (modules) that exists in the learner. Use `self.learn.modules` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.135960</td>
#       <td>0.996719</td>
#       <td>0.587646</td>
#       <td>00:27</td>
#     </tr>
#   </tbody>
# </table>

# %%
#learn.recorder.plot_sched()
# x-axis batch progression
# works with fit_one_cycle

# %%
learn.activation_stats.plot_layer_stats(-2)

# %%
learn.activation_stats.color_dim(-2)

# %%
# increase batch size
dls_128 = dblock.dataloaders(path/'/content/planets_8/', bs = 128)

learn = Learner(dls_128, cnn,
                loss_func = F.cross_entropy,
                metrics = accuracy,
                cbs = ActivationStats(with_hist=True))
learn.fit_one_cycle(n_epoch = 1, lr_max = 0.003) #
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/callback/core.py:51: UserWarning: You are shadowing an attribute (modules) that exists in the learner. Use `self.learn.modules` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.044222</td>
#       <td>0.967533</td>
#       <td>0.594324</td>
#       <td>00:27</td>
#     </tr>
#   </tbody>
# </table>

# %%
#use
dls_128 = dblock.dataloaders(path/'/content/planets_8/', bs = 128)

learn = Learner(dls_128, cnn,
                loss_func = F.cross_entropy,
                metrics = accuracy,
                cbs = ActivationStats(with_hist=True))
learn.fit_one_cycle(n_epoch = 5, lr_max = 0.003) #
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/callback/core.py:51: UserWarning: You are shadowing an attribute (modules) that exists in the learner. Use `self.learn.modules` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.980110</td>
#       <td>0.960468</td>
#       <td>0.626043</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.962355</td>
#       <td>0.957225</td>
#       <td>0.654424</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.962100</td>
#       <td>1.111399</td>
#       <td>0.540901</td>
#       <td>00:27</td>
#     </tr>
# ...

# %%
# remove relu and bnorm on first 2
cnn_b = sequential(
    (nn.Conv2d(in_channels = 3, out_channels = 8, # 
              kernel_size = 5,
              stride=2,
               padding = 5//2)),# 100
    #(nn.BatchNorm2d(8)), 
    #(nn.ReLU()),

    (nn.Conv2d(in_channels = 8, out_channels = 16,
          kernel_size = 5,
          stride=2,
          padding =5//2)), # 50
    #(nn.BatchNorm2d(16)), 
    #(nn.ReLU()), 
    
    (nn.Conv2d(in_channels = 16, out_channels = 32,
          kernel_size = 5,
          stride=2,
          padding=5//2)), # 25
    (nn.BatchNorm2d(32)), 
    (nn.ReLU()),

    (nn.Conv2d(in_channels = 32, out_channels = 64,
          kernel_size = 5,
          stride=2,
          padding=5//2)), # 13
    (nn.BatchNorm2d(64)), 
    (nn.ReLU()),

    (nn.Conv2d(in_channels = 64, out_channels = 128,
          kernel_size = 5,
          stride=2,
          padding=5//2)), # 7
    (nn.BatchNorm2d(128)), 
    (nn.ReLU()),

    (nn.Conv2d(in_channels = 128, out_channels = 256,
          kernel_size = 3,
          stride=2,
          padding=3//2)), # 4
    (nn.BatchNorm2d(256)), 
    (nn.ReLU()),

    (nn.Conv2d(in_channels = 256, out_channels = 512,
          kernel_size = 3,
          stride=2,
          padding=3//2)), # 2
    (nn.BatchNorm2d(512)), 
    (nn.ReLU()),

    (nn.Conv2d(in_channels = 512, out_channels = 4,##
          kernel_size = 3,
          stride=2,
          padding =3//2)), # 1
          
    (Flatten())
)

# %%
#use
dls = dblock.dataloaders(path/'/content/planets_8/',)

learn_b = Learner(dls, cnn_b,
                loss_func = F.cross_entropy,
                metrics = accuracy,
                cbs = ActivationStats(with_hist=True))
learn_b.fit_one_cycle(n_epoch = 1, lr_max = 0.003) #
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/callback/core.py:51: UserWarning: You are shadowing an attribute (modules) that exists in the learner. Use `self.learn.modules` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.116061</td>
#       <td>1.047350</td>
#       <td>0.597663</td>
#       <td>00:29</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.activation_stats.plot_layer_stats(0)

# %%
learn.activation_stats.plot_layer_stats(1)

# %%
learn.activation_stats.plot_layer_stats(2)

# %%
learn.activation_stats.plot_layer_stats(3)

# %%
learn.activation_stats.plot_layer_stats(4)

# %%
learn.activation_stats.plot_layer_stats(5)

# %%
learn.activation_stats.plot_layer_stats(6)

# %%
learn.activation_stats.plot_layer_stats(7)

# %%
learn.activation_stats.plot_layer_stats(8)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-81-f87cc8e926bd> in <module>()
# ----> 1 learn.activation_stats.plot_layer_stats(8)
#
# /usr/local/lib/python3.7/dist-packages/fastai/callback/hook.py in plot_layer_stats(self, idx)
#     271     def plot_layer_stats(self, idx):
#     272         _,axs = subplots(1, 3, figsize=(12,3))
# --> 273         for o,ax,title in zip(self.layer_stats(idx),axs,('mean','std','% near zero')):
#     274             ax.plot(o)
#     275             ax.set_title(title)
#
# /usr/local/lib/python3.7/dist-packages/fastai/callback/hook.py in layer_stats(self, idx)
#     255
#     256     def layer_stats(self, idx):
# --> 257         lstats = self.stats.itemgot(idx)
#     258         return L(lstats.itemgot(o) for o in ('mean','std','near_zero'))
#     259
#
# ...
